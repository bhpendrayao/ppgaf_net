# %%
import os
import shutil
import random
import pathlib

# Set the source directories
from google.colab import drive
import pathlib
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define base path for your project in Google Drive
base_path = pathlib.Path("/content/drive/My Drive/FYP")

# Define source directories for AF and Non-AF PPM data
af_ppm_dir = base_path / "MimicPerform20ss"
non_af_ppm_dir = base_path / "MimicPerform20ss"
print(af_ppm_dir)
print(non_af_ppm_dir)

# Define the number of partitions and users for each
num_partitions = 10
num_af_users = 19
num_non_af_users = 16

# Define the destination directory for partitions in Google Drive
for partition_num in range(1, num_partitions + 1):
    print(f'Creating partition {partition_num}............................................................')

    # Update train and test destinations to save on Google Drive
    train_dest = str(base_path / f'MimicPerformAF_15AF13/Part{partition_num}/Train/')
    test_dest = str(base_path / f'MimicPerformAF_15AF13/Part{partition_num}/Test/')
    print(train_dest)
    print(test_dest)

    # Check if partition folders already exist with content
    if os.path.exists(train_dest) and os.listdir(train_dest):
        print(f'Partition {partition_num} already exists with content, skipping.')
        continue

    # Create directories if they don't exist
    os.makedirs(train_dest, exist_ok=True)
    os.makedirs(test_dest, exist_ok=True)
    print(f'Partition {partition_num} created successfully.')


    # Create the directories if they don't exist
    os.makedirs(train_dest, exist_ok=True)
    os.makedirs(test_dest, exist_ok=True)

    # Randomly shuffle the user IDs
    af_user_ids = list(range(1, num_af_users + 1))
    non_af_user_ids = list(range(1, num_non_af_users + 1))
    random.shuffle(af_user_ids)
    random.shuffle(non_af_user_ids)

    # Calculate the number of users for training and testing
    num_af_train_users = 15
    num_non_af_train_users = 13
    num_af_test_users = num_af_users - num_af_train_users
    num_non_af_test_users = num_non_af_users - num_non_af_train_users

    # Split users into training and testing
    af_train_users = af_user_ids[:num_af_train_users]
    non_af_train_users = non_af_user_ids[:num_non_af_train_users]
    af_test_users = af_user_ids[num_af_train_users:]
    non_af_test_users = non_af_user_ids[num_non_af_train_users:]

    # Copy all files for each user to the appropriate partitions
    for user_id in af_train_users:
        src_dir = af_ppm_dir
        dest_dir = os.path.join(train_dest, 'AF')
        os.makedirs(dest_dir, exist_ok=True)
        if os.path.exists(src_dir):
            print('AF train users: ', af_train_users)
            # Iterate through all files in the source directory and copy the ones matching user_id
            for file_name in os.listdir(src_dir):
                if file_name.startswith(f'AF_mimic_perform_af_{user_id:03d}'):
                    src_path = os.path.join(src_dir, file_name)
                    dest_path = os.path.join(dest_dir, file_name)
                    print(src_path)
                    print(dest_path)
                    shutil.copy(src_path, dest_path)
        else:
            print('Path not found: ', src_dir)

    for user_id in non_af_train_users:
        src_dir = non_af_ppm_dir
        dest_dir = os.path.join(train_dest, 'Non_AF')
        os.makedirs(dest_dir, exist_ok=True)
        if os.path.exists(src_dir):
            print('Non AF train users: ', non_af_train_users)
            # Iterate through all files in the source directory and copy the ones matching user_id
            for file_name in os.listdir(src_dir):
                if file_name.startswith(f'Non_AF_mimic_perform_non_af_{user_id:03d}'):
                    src_path = os.path.join(src_dir, file_name)
                    dest_path = os.path.join(dest_dir, file_name)
                    print(src_path)
                    print(dest_path)
                    shutil.copy(src_path, dest_path)

        else:
            print('Path not found: ', src_dir)


    for user_id in af_test_users:
        src_dir = af_ppm_dir
        dest_dir = os.path.join(test_dest, 'AF')
        os.makedirs(dest_dir, exist_ok=True)
        if os.path.exists(src_dir):
            print('AF test users: ', af_test_users)
            # Iterate through all files in the source directory and copy the ones matching user_id
            for file_name in os.listdir(src_dir):
                if file_name.startswith(f'AF_mimic_perform_af_{user_id:03d}'):
                    src_path = os.path.join(src_dir, file_name)
                    dest_path = os.path.join(dest_dir, file_name)
                    print(src_path)
                    print(dest_path)
                    shutil.copy(src_path, dest_path)
        else:
            print('Path not found: ', src_dir)

    for user_id in non_af_test_users:
        src_dir = non_af_ppm_dir
        dest_dir = os.path.join(test_dest, 'Non_AF')
        os.makedirs(dest_dir, exist_ok=True)
        if os.path.exists(src_dir):
            print('Non AF test users: ', non_af_test_users)
            # Iterate through all files in the source directory and copy the ones matching user_id
            for file_name in os.listdir(src_dir):
                if file_name.startswith(f'Non_AF_mimic_perform_non_af_{user_id:03d}'):
                    src_path = os.path.join(src_dir, file_name)
                    dest_path = os.path.join(dest_dir, file_name)
                    shutil.copy(src_path, dest_path)
        else:
            print('Path not found: ', src_dir)

print(f'Partition {partition_num} completed.')

print('All partitions created successfully.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/FYP/MimicPerform20ss
# /content/drive/My Drive/FYP/MimicPerform20ss
# Creating partition 1............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part1/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part1/Test
# Partition 1 already exists with content, skipping.
# Creating partition 2............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part2/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part2/Test
# Partition 2 already exists with content, skipping.
# Creating partition 3............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part3/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part3/Test
# Partition 3 already exists with content, skipping.
# Creating partition 4............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part4/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part4/Test
# Partition 4 already exists with content, skipping.
# Creating partition 5............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part5/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part5/Test
# Partition 5 already exists with content, skipping.
# Creating partition 6............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part6/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part6/Test
# Partition 6 already exists with content, skipping.
# Creating partition 7............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part7/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part7/Test
# Partition 7 already exists with content, skipping.
# Creating partition 8............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part8/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part8/Test
# Partition 8 already exists with content, skipping.
# Creating partition 9............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part9/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part9/Test
# Partition 9 already exists with content, skipping.
# Creating partition 10............................................................
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part10/Train
# /content/drive/My Drive/FYP/MimicPerformAF_15AF13/Part10/Test
# Partition 10 already exists with content, skipping.
# Partition 10 completed.
# All partitions created successfully.
